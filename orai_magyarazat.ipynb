# %%
# !pip install pymongo
import pandas as pd

# %%
from pymongo import MongoClient
import pymongo

# %%
#a connectionstring a MongoDB Astra-ból vagy a MongoDB Compass-ból kapható meg
client = pymongo.MongoClient("mongodb+srv://maricaveress:Macijaja.03@cluster0.xyprukq.mongodb.net/")

# %%
#valamelyik adatbázishoz csatlakozni kell
db = client.sample_mflix

# %%
#tetszőleges parancsok kiadása
#pl. filmek keresése:
ered = db.movies.find()

# %%
for i in ered:
    print(i["genres"])
# Out:
# ['Drama']
# ['Drama']
# ['Drama', 'Romance']
# ['Drama', 'War']
# ['Drama', 'Musical']
# ['Drama']
# ['Crime', 'Drama', 'Romance']
# ['Comedy']
# ['Drama', 'Romance', 'Adventure']
# ['Comedy', 'Musical', 'Romance']
# ['Drama']
# ['Comedy', 'Drama']
# ['Crime', 'Film-Noir', 'Mystery']
# ['Comedy', 'Fantasy', 'Horror']
# ['Drama', 'Romance']
# ['Comedy', 'Musical', 'Romance']
# ['Comedy', 'History']
# ['Adventure', 'Drama', 'Romance']
# ['Drama']
# ['Comedy', 'Drama', 'Musical']
# ['Action', 'Adventure', 'Drama']
# ['Animation', 'Family', 'Musical']
# ['Adventure', 'Comedy', 'Drama']
# ['Drama']
# ['Drama']
# ['Comedy', 'Drama', 'Romance']
# ['Musical', 'Fantasy']
# ['Documentary', 'War']
# ['Drama', 'Romance', 'Thriller']
# ['Animation', 'Family', 'Music']
# ['Drama', 'Romance']
# ['Comedy', 'Drama', 'Family']
# ['Drama']
# ['Comedy']
# ['Western']
# ['Animation', 'Family', 'Music']
# ['Drama', 'Film-Noir', 'Thriller']
# ['Drama']
# ['Drama', 'Family', 'Romance']
# ...

# %%
#akár berakhatunk mident egy dataframe-be
adatok = pd.DataFrame(ered)
#utána bármit lehet vele csinálni
adatok.head()
# Out:
#                         _id  \
# 0  573a1393f29313caabcdd943
# 1  573a1393f29313caabcdd9af
# 2  573a1393f29313caabcdd9da
# 3  573a1393f29313caabcddb58
# 4  573a1393f29313caabcddbb8
#
#                                                 plot  \
# 0  A minister falls in love with a blind young wo...
# 1  A boy persuades his parents to allow him to ad...
# 2  After Japan's loss in the war, the wealthy, cu...
# 3  With his law-breaking lifestyle in the past, a...
# 4  St. Vincent de Paul struggles to bring about p...
#
#                         genres  runtime     rated  \
# 0                      [Drama]    110.0  APPROVED
# 1              [Drama, Family]    128.0  APPROVED
# 2                      [Drama]     89.0       NaN
# 3    [Crime, Drama, Film-Noir]     98.0  APPROVED
# 4  [Biography, Drama, History]    111.0       NaN
#
#                                                 cast  num_mflix_comments  \
# 0  [Michèle Morgan, Pierre Blanchar, Line Noro, J...                   0
# ...
